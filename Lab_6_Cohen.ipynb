# %% [markdown]
# <a href="https://colab.research.google.com/github/brandoncohen23/Probability_Statistics-1/blob/main/Lab_6_Cohen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab Notebook #6

# %%
import numpy as np # imports programs for notebook
import matplotlib.pyplot as plt

import pandas as pd
import urllib.request

# %%
url = "https://raw.githubusercontent.com/brandoncohen23/Probability_Statistics-1/main/cereal_data.csv" # raw data url

# %%
urllib.request.urlretrieve(url,'cereal_data.csv') # requests the data
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f8e04696dd0>)

# %%
cereal_data = pd.read_csv('cereal_data.csv') # defines cereal_data as the actual data

# %%
cereal_data # shows the data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"] # shows sugars data
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
cereal_data[["calories","sugars"]] # shows calories and sugars data
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
cereal_data["sugars"].mean() # mean of sugars data
# Out:
# 6.922077922077922

# %%
cereal_data[["calories","sugars"]].mean() # mean of both calories and sugars data
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe() # desrcibes the cereal data with many values
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.') # creates a graph for sugars and calories

# %%
x = cereal_data[["sugars"]] # creates a complete graph with labels
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("Sugars")
plt.ylabel("Calories")
plt.title("Sugars vs Calories")
# Out:
# Text(0.5, 1.0, 'Sugars vs Calories')

# %%
x = cereal_data[["fat"]] # graph about fats and calories
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("Fat")
plt.ylabel("Calories")
plt.title("Fat vs Calories")
# Out:
# Text(0.5, 1.0, 'Fat vs Calories')

# %%
x = cereal_data[["fiber"]] # fiber and potassium graph
y = cereal_data[["potass"]]

plt.plot(x,y,'.')
plt.xlabel("Fiber")
plt.ylabel("Potassium")
plt.title("Fiber vs Potassium")
# Out:
# Text(0.5, 1.0, 'Fiber vs Potassium')

# %%
X = cereal_data[["fiber"]] # assigns data to the x and y values
Y = cereal_data[["potass"]]

# %%
from sklearn.linear_model import LinearRegression # linear regression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X,Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X,Y,".") # displays linear regression on graph
plt.plot(X,Y_pred, color = 'red')
plt.show()

# %%
x = np.linspace(0,10,50) # adjust the graph points

# %%
x # array of x values
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
m = 3 # assigns the values numbers for the equation
b = 7

y = m * x + b

# %%
noise = 10 * np.random.randn(50,) # defines noise

# %%
y = m * x + b + noise # putting noise and the slope intercept equation together

# %%
plt.plot(x,y,'.') # plots the graph

# %%
m_guess = 5 # guesses for the values
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess, 'r.');
plt.plot(x,y,"g.");

# %%
loss = np.sum((y_guess - y)**2) # defines loss

# %%
for m_guess in np.linspace(-10,10,10): # prints m_guess
    print(m_guess)
# Out:
# -10.0
# -7.777777777777778
# -5.555555555555555
# -3.333333333333333
# -1.1111111111111107
# 1.1111111111111107
# 3.333333333333334
# 5.555555555555557
# 7.777777777777779
# 10.0

# %%
for m_guess in np.linspace(-10,10,10): # creates graph with the guesses
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
#